# %% [markdown]
# # Домашнее задание 3 - PANDAS
#
# ### Выполнила: Иванова Елизавета Дмитриевна, НПМбд-01-19

# %% [markdown]
# <img src = "https://lookw.ru/1/75/1380310853-pandi----37.jpg">
#
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки pandas и визуализации с помощью matplotlib. В каждом разделе вам предлагается выполнить несколько заданий. Баллы даются за выполнение отдельных пунктов. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотекам pandas и matplotlib.

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных. С этой библиотекой мы сейчас и познакомимся.
#
# Основной объект в pandas это DataFrame, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и stackoverflow.

# %% [markdown]
# Данные можно скачать [отсюда](https://www.dropbox.com/s/5qq94wzmbw4e54r/data.csv?dl=0).

# %%
# %pylab inline  
# import almost all we need
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pass_data = pd.read_csv('data.csv')
pass_data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# #### 1. [0.5 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите последние 10 строк.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы?

# %%
pass_data.tail(10)
# Out:
#       order_id  quantity            item_name  \
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25
# 4613                                                NaN     $2.15
# 4614                                                NaN     $1.50
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %% [markdown]
# #### 2. [0.25 баллов] Ответьте на вопросы:
# 1. Сколько заказов попало в выборку?
# 2. Сколько уникальных категорий товара было куплено? (item_name)

# %%
number_of_orders = len(set(pass_data['order_id'])) 
number_of_unique = len(set(pass_data['item_name'])) 

print("1. ", number_of_orders, "\n2. ", number_of_unique)
# Out:
# 1.  1834
# 2.  50

# %% [markdown]
# #### 3. [0.25 баллов] Есть ли в данных пропуски? В каких колонках?

# %%
true_or_false = pass_data.isna().any()
column_name = true_or_false[true_or_false == True].keys()

for i in true_or_false:    
    if true_or_false.any() == True:
        print("1. Да")
        print("2.", list(column_name)[0])
        break
# Out:
# 1. Да
# 2. choice_description

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок и нулём для числовых.

# %%
for i in pass_data.columns:
    
    if np.dtype(pass_data[i]) == int:
        pass_data[i].fillna(value=0, inplace=True)
        
    if np.dtype(pass_data[i]) == object:
        pass_data[i].fillna(value='', inplace=True)

# %%
 pass_data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                           $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                           $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# #### 4. [0.5 баллов] Посмотрите внимательнее на колонку с ценой товара. Какого она типа? Создайте новую колонку так, чтобы в ней цена была числом.
#
# Для этого попробуйте применить функцию-преобразование к каждой строке вашей таблицы (для этого есть соответствующая функция).

# %%
print(pass_data['item_price'].dtype)
# Out:
# object

# %%
def to_float(x):
    return float(x.replace('$', ''))
    

pass_data['item_price_float'] = pass_data['item_price'].apply(to_float)
pass_data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 0                                                           $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                           $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
#       item_price_float
# 0                 2.39
# 1                 3.39
# 2                 3.39
# 3                 2.39
# 4                16.98
# ...                ...
# 4617             11.75
# 4618             11.75
# 4619             11.25
# 4620              8.75
# 4621              8.75
#
# [4622 rows x 6 columns]

# %%
print(pass_data['item_price_float'].dtype)
# Out:
# float64

# %% [markdown]
# Какая средняя/минимальная/максимальная цена у товара?

# %%
pass_data['price_of_one_item'] = pass_data['item_price_float'] / pass_data['quantity']
pass_data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 0                                                           $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                           $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
#       item_price_float  price_of_one_item
# 0                 2.39               2.39
# 1                 3.39               3.39
# 2                 3.39               3.39
# 3                 2.39               2.39
# 4                16.98               8.49
# ...                ...                ...
# 4617             11.75              11.75
# 4618             11.75              11.75
# 4619             11.25              11.25
# 4620              8.75               8.75
# 4621              8.75               8.75
#
# [4622 rows x 7 columns]

# %%
print("Средняя: ", pass_data.drop_duplicates(['item_name', 'price_of_one_item'])['price_of_one_item'].mean())
# Out:
# Средняя:  8.55870503597123

# %%
print("Минимальная: ", pass_data['price_of_one_item'].min())
# Out:
# Минимальная:  1.09

# %%
print("Максимальная: ", pass_data['price_of_one_item'].max())
# Out:
# Максимальная:  11.89

# %% [markdown]
# Удалите старую колонку с ценой.

# %%
item_price_drop = pass_data.drop(columns = 'item_price')
item_price_drop
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price_float  \
# 0                                                                    2.39
# 1                                          [Clementine]              3.39
# 2                                               [Apple]              3.39
# 3                                                                    2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...             16.98
# ...                                                 ...               ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...             11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...             11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...             11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...              8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...              8.75
#
#       price_of_one_item
# 0                  2.39
# 1                  3.39
# 2                  3.39
# 3                  2.39
# 4                  8.49
# ...                 ...
# 4617              11.75
# 4618              11.75
# 4619              11.25
# 4620               8.75
# 4621               8.75
#
# [4622 rows x 6 columns]

# %% [markdown]
# #### 5. [0.25 баллов] Какие 5 товаров были самыми дешёвыми и самыми дорогими? (по item_name)
#
# Для этого будет удобно избавиться от дубликатов и отсортировать товары. Не забудьте про количество товара.

# %%
sort = pass_data.sort_values('price_of_one_item')
sort
# Out:
#       order_id  quantity            item_name  \
# 3364      1349         2          Canned Soda
# 818        338         3        Bottled Water
# 1182       485         2        Bottled Water
# 162         73         2          Canned Soda
# 821        338         1          Canned Soda
# ...        ...       ...                  ...
# 4239      1692         1  Carnitas Salad Bowl
# 1229       501         1  Barbacoa Salad Bowl
# 2439       969         1     Steak Salad Bowl
# 2442       970         1  Barbacoa Salad Bowl
# 2401       953         1     Steak Salad Bowl
#
#                                      choice_description item_price  \
# 3364                                        [Coca Cola]     $2.18
# 818                                                         $3.27
# 1182                                                        $2.18
# 162                                         [Diet Coke]     $2.18
# 821                                         [Coca Cola]     $1.09
# ...                                                 ...        ...
# 4239  [Tomatillo Green Chili Salsa, [Black Beans, Ch...    $11.89
# 1229  [Fresh Tomato Salsa, [Rice, Fajita Vegetables,...    $11.89
# 2439  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.89
# 2442  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...    $11.89
# 2401  [Fresh Tomato Salsa, [Fajita Vegetables, Guaca...    $11.89
#
#       item_price_float  price_of_one_item
# 3364              2.18               1.09
# 818               3.27               1.09
# 1182              2.18               1.09
# 162               2.18               1.09
# 821               1.09               1.09
# ...                ...                ...
# 4239             11.89              11.89
# 1229             11.89              11.89
# 2439             11.89              11.89
# 2442             11.89              11.89
# 2401             11.89              11.89
#
# [4622 rows x 7 columns]

# %%
cheap = sort.drop_duplicates(['item_name']).head(5)
cheap.loc[:, ['item_name', 'price_of_one_item']]
# Out:
#               item_name  price_of_one_item
# 3364        Canned Soda               1.09
# 818       Bottled Water               1.09
# 4200  Canned Soft Drink               1.25
# 4057      Side of Chips               1.69
# 4509              Chips               1.99

# %%
expensive = sort[::-1].drop_duplicates(['item_name']).head(5)
expensive.loc[:, ['item_name', 'price_of_one_item']]
# Out:
#                 item_name  price_of_one_item
# 2401     Steak Salad Bowl              11.89
# 2442  Barbacoa Salad Bowl              11.89
# 4239  Carnitas Salad Bowl              11.89
# 462      Carnitas Burrito              11.75
# 4262        Steak Burrito              11.75

# %% [markdown]
# #### 6. [0.5 баллов] Сколько раз клиенты покупали больше 1 Chicken Bowl (item_name)?

# %%
Chicken_Bowl = pass_data[(pass_data['quantity'] > 1) & (pass_data['item_name'] == 'Chicken Bowl')]

len(Chicken_Bowl)
# Out:
# 33

# %% [markdown]
# #### 7. [0.5 баллов] Какой средний чек у заказа? Сколько в среднем товаров покупают?
#
# Если необходимо провести вычисления в терминах заказов, то будет удобно сгруппировать строки по заказам и посчитать необходимые статистики.

# %%
average_check = pass_data.groupby('order_id')['item_price_float'].sum().mean()
average_number_of_goods = pass_data.groupby('order_id')['quantity'].sum().mean()

print("Средний чек: ", average_check)
print("Cреднее количество товаров: ", average_number_of_goods)
# Out:
# Средний чек:  18.81142857142869
# Cреднее количество товаров:  2.711014176663032

# %% [markdown]
# #### 8. [0.25 баллов] Сколько заказов содержали ровно 1 товар?

# %%
quantity = pass_data.groupby('order_id')['quantity'].sum()
list(quantity).count(1)
# Out:
# 56

# %% [markdown]
# #### 9. [0.25 баллов] Какая самая популярная категория товара?

# %%
item = pass_data.groupby('item_name')['quantity'].sum()
popular_item_quantity = item.sort_values()[::-1].head(1)
popular_item_name = popular_item_quantity.keys()

print("Наименованиe:", list(popular_item_name)[0])
print("Количecтво:", int(popular_item_quantity))
# Out:
# Наименованиe: Chicken Bowl
# Количecтво: 761

# %% [markdown]
# #### 10. [0.5 баллов] Какие виды Burrito существуют? Какой из них чаще всего покупают? Какой из них самый дорогой?

# %%
Burrito = pass_data['item_name'].str.contains('Burrito')
types_of_burritos = pass_data[Burrito]['item_name'].drop_duplicates()

print("Виды буррито:\n", *list(types_of_burritos), sep = '\n')
# Out:
# Виды буррито:
#
# Steak Burrito
# Chicken Burrito
# Barbacoa Burrito
# Carnitas Burrito
# Veggie Burrito
# Burrito

# %%
Burrito_quantity = pass_data[Burrito].groupby('item_name')['quantity'].sum()
popular_Burrito_quantity = Burrito_quantity.sort_values()[::-1] .head(1)
popular_Burrito_name = popular_Burrito_quantity.keys()

print("Чаще всего покупают:", list(popular_Burrito_name)[0])
# Out:
# Чаще всего покупают: Chicken Burrito

# %%
Burrito_price = pass_data[Burrito & (pass_data['quantity'] == 1)].sort_values('price_of_one_item')
expensive_Burrito = Burrito_price[::-1].drop_duplicates('item_name')
expensive_Burrito_name = expensive_Burrito['item_name']

# %%
expensive_Burrito.drop_duplicates('item_name')
# Out:
#       order_id  quantity         item_name  \
# 4618      1833         1     Steak Burrito
# 2523      1003         1  Carnitas Burrito
# 2718      1079         1  Barbacoa Burrito
# 1957       791         1   Chicken Burrito
# 1982       801         1    Veggie Burrito
# 510        214         1           Burrito
#
#                                      choice_description item_price  \
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 2523  [Tomatillo Red Chili Salsa, [Black Beans, Chee...    $11.75
# 2718  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.75
# 1957  [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $11.25
# 1982  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...    $11.25
# 510   [Adobo-Marinated and Grilled Chicken, Pinto Be...     $7.40
#
#       item_price_float  price_of_one_item
# 4618             11.75              11.75
# 2523             11.75              11.75
# 2718             11.75              11.75
# 1957             11.25              11.25
# 1982             11.25              11.25
# 510               7.40               7.40

# %%
print("Самые дорогие:", ', '.join(list(expensive_Burrito_name[0:3])))
# Out:
# Самые дорогие: Steak Burrito, Carnitas Burrito, Barbacoa Burrito

# %% [markdown]
# #### 11. [0.75 баллов] В каком количестве заказов есть товар, который стоит более 40% от суммы всего чека?
#
# Возможно, будет удобно посчитать отдельно среднюю стоимость заказа, добавить ее в исходные данные и сделать необходимые проверки.
#
# *Данный комментарий стоит воспринимать как подсказку к одному из вариантов решений задания. Если в вашем варианте решения он не нужнен, это не страшно*

# %%
check_amount = np.array(pass_data.groupby('order_id')['item_price_float'].sum())
max_price = np.array(pass_data.groupby('order_id')['price_of_one_item'].max())

number_of_orders = 0

for i in range(len(check_amount)):
    
    if max_price[i] / check_amount[i] > 0.4:
        number_of_orders += 1
        
print("Количество заказов, в которых есть товар, который стоит более 40% от суммы всего чека:", number_of_orders)
# Out:
# Количество заказов, в которых есть товар, который стоит более 40% от суммы всего чека: 1589

# %% [markdown]
# #### 12. [0.75 баллов] Предположим, что в данных была ошибка и Diet Coke (choice_description), который стоил $1.25, должен был стоить 1.35. Скорректируйте данные в таблицы и посчитайте, на какой процент больше денег было заработано с этого товара. Не забывайте, что количество товара не всегда равно 1.

# %%
Diet_Coke = pass_data[pass_data['choice_description'].str.contains('Diet Coke') & (pass_data['price_of_one_item'] == 1.25)]
Old_Price = np.array(Diet_Coke['item_price_float'])
Adjusted_Price = np.array(Diet_Coke['quantity']) * 1.35

benefit = (sum(Adjusted_Price) - sum(Old_Price)) / sum(Old_Price)

print("Выгода:", benefit * 100, "%")
# Out:
# Выгода: 7.9999999999999805 %

# %% [markdown]
# #### 13. [0.75 баллов] Создайте новый DateFrame из матрицы, созданной ниже. Назовите колонки index, column1, column2 и сделайте первую колонку индексом.

# %% [markdown]
# Возьмём матрицу со случайными целыми числами:

# %%
Data_Frame_1 = pd.DataFrame(columns = ['index', 'column1', 'column2'])
Data_Frame_1 = Data_Frame_1.set_index('index')

for i in range(10):
    Data_Frame_1 = Data_Frame_1.append({'column1': np.random.randint(10,100), 
                                        'column2': np.random.randint(10,100)}, ignore_index=True)

Data_Frame_1
# Out:
#   column1 column2
# 0      73      79
# 1      26      64
# 2      69      70
# 3      84      76
# 4      26      15
# 5      30      68
# 6      41      13
# 7      53      31
# 8      87      41
# 9      22      20

# %% [markdown]
# Сохраните DataFrame на диск в формате csv без индексов и названий столбцов.

# %%
Data_Frame_1.to_csv('Data_Frame_1_Without_Header.csv', index=False, header=False)

lets_read = pd.read_csv('Data_Frame_1_Without_Header.csv')
lets_read
# Out:
#    73  79
# 0  26  64
# 1  69  70
# 2  84  76
# 3  26  15
# 4  30  68
# 5  41  13
# 6  53  31
# 7  87  41
# 8  22  20

# %%
Data_Frame_1.to_csv('Data_Frame_1_With_Header.csv', index=False)

lets_read = pd.read_csv('Data_Frame_1_With_Header.csv')
lets_read
# Out:
#    column1  column2
# 0       73       79
# 1       26       64
# 2       69       70
# 3       84       76
# 4       26       15
# 5       30       68
# 6       41       13
# 7       53       31
# 8       87       41
# 9       22       20

# %% [markdown]
# Возьмём матрицу со случайными числами:

# %%
data = np.random.rand(10,3)

# %%
Data_Frame_2 = pd.DataFrame(data, columns = ['index', 'column1', 'column2'])
Data_Frame_2
# Out:
#       index   column1   column2
# 0  0.830341  0.507553  0.003607
# 1  0.698465  0.568613  0.355865
# 2  0.139986  0.378794  0.859216
# 3  0.014061  0.946189  0.301276
# 4  0.281332  0.819727  0.223254
# 5  0.568142  0.941160  0.873858
# 6  0.069083  0.817878  0.966089
# 7  0.960374  0.377163  0.610285
# 8  0.451386  0.068677  0.443660
# 9  0.152744  0.496731  0.591831

# %%
Data_Frame_2.to_csv('Data_Frame_2_Without_Header.csv', index=False, header=False)

lets_read = pd.read_csv('Data_Frame_2_Without_Header.csv')
lets_read
# Out:
#    0.8303408095908964  0.5075526420461363  0.0036065381576603217
# 0            0.698465            0.568613               0.355865
# 1            0.139986            0.378794               0.859216
# 2            0.014061            0.946189               0.301276
# 3            0.281332            0.819727               0.223254
# 4            0.568142            0.941160               0.873858
# 5            0.069083            0.817878               0.966089
# 6            0.960374            0.377163               0.610285
# 7            0.451386            0.068677               0.443660
# 8            0.152744            0.496731               0.591831

# %%
Data_Frame_2.to_csv('Data_Frame_2_With_Header.csv', index=False)

lets_read = pd.read_csv('Data_Frame_2_With_Header.csv')
lets_read
# Out:
#       index   column1   column2
# 0  0.830341  0.507553  0.003607
# 1  0.698465  0.568613  0.355865
# 2  0.139986  0.378794  0.859216
# 3  0.014061  0.946189  0.301276
# 4  0.281332  0.819727  0.223254
# 5  0.568142  0.941160  0.873858
# 6  0.069083  0.817878  0.966089
# 7  0.960374  0.377163  0.610285
# 8  0.451386  0.068677  0.443660
# 9  0.152744  0.496731  0.591831

# %%
Data_Frame_3 = pd.DataFrame(data, columns = ['index', 'column1', 'column2'])
Data_Frame_3 = Data_Frame_3.set_index('index')
Data_Frame_3
# Out:
#            column1   column2
# index
# 0.830341  0.507553  0.003607
# 0.698465  0.568613  0.355865
# 0.139986  0.378794  0.859216
# 0.014061  0.946189  0.301276
# 0.281332  0.819727  0.223254
# 0.568142  0.941160  0.873858
# 0.069083  0.817878  0.966089
# 0.960374  0.377163  0.610285
# 0.451386  0.068677  0.443660
# 0.152744  0.496731  0.591831

# %%
Data_Frame_3.to_csv('Data_Frame_3_Without_Header.csv', index=False, header=False)

lets_read = pd.read_csv('Data_Frame_3_Without_Header.csv')
lets_read
# Out:
#    0.5075526420461363  0.0036065381576603217
# 0            0.568613               0.355865
# 1            0.378794               0.859216
# 2            0.946189               0.301276
# 3            0.819727               0.223254
# 4            0.941160               0.873858
# 5            0.817878               0.966089
# 6            0.377163               0.610285
# 7            0.068677               0.443660
# 8            0.496731               0.591831

# %%
Data_Frame_3.to_csv('Data_Frame_3_With_Header.csv', index=False)

lets_read = pd.read_csv('Data_Frame_3_With_Header.csv')
lets_read
# Out:
#     column1   column2
# 0  0.507553  0.003607
# 1  0.568613  0.355865
# 2  0.378794  0.859216
# 3  0.946189  0.301276
# 4  0.819727  0.223254
# 5  0.941160  0.873858
# 6  0.817878  0.966089
# 7  0.377163  0.610285
# 8  0.068677  0.443660
# 9  0.496731  0.591831

# %% [markdown]
# <img src = "https://img5.goodfon.ru/original/2880x1800/f/5f/medved-medvezhonok-panda-zabor-malysh-brevno.jpg">

# %% [markdown]
# ## 2. Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. В этом разделе мы этим и займёмся.
#
# У matplotlib, конечно, же есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторое величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить каждый из них. Не менее важно усвоить базовые принципы визуализаций:
# - на графиках должны быть подписаны оси;
# - у визуализации должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах).
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# На самом деле мы уже импортировали matplotlib внутри %pylab inline в начале задания.
#
# Работать мы будем с той же выборкой покупкок. Добавим новую колонку с датой покупки.

# %%
import datetime

df = pass_data.copy(deep=True)

start = datetime.datetime(2018, 1, 1)
end = datetime.datetime(2018, 1, 31)
delta_seconds = int((end - start).total_seconds())

dates = pd.DataFrame(index=df.order_id.unique())
dates['date'] = [
    (start + datetime.timedelta(seconds=random.randint(0, delta_seconds))).strftime('%Y-%m-%d')
    for _ in range(df.order_id.nunique())]

df['date'] = df.order_id.map(dates['date'])

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 0                                                           $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                           $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
#       item_price_float  price_of_one_item        date
# 0                 2.39               2.39  2018-01-16
# 1                 3.39               3.39  2018-01-16
# 2                 3.39               3.39  2018-01-16
# 3                 2.39               2.39  2018-01-16
# 4                16.98               8.49  2018-01-27
# ...                ...                ...         ...
# 4617             11.75              11.75  2018-01-25
# 4618             11.75              11.75  2018-01-25
# 4619             11.25              11.25  2018-01-16
# 4620              8.75               8.75  2018-01-16
# 4621              8.75               8.75  2018-01-16
#
# [4622 rows x 8 columns]

# %% [markdown]
# #### 1. [1 балл] Постройте гистограмму распределения сумм покупок и гистограмму средних цен отдельных видов продуктов item_name.
#
# Изображайте на двух соседних графиках. Для этого может быть полезен subplot.

# %%
purchase_amount = df.groupby('order_id')['item_price_float'].sum()
average_price = df.groupby('item_name')['price_of_one_item'].mean()

# %%
fig, ax = plt.subplots(1, 2, figsize=(22, 10))
ax[0].set_title('\nГистограмма распределения сумм покупок\n', fontsize = 20)
ax[1].set_title('\nГистограмма средних цен отдельных видов продуктов\n', fontsize = 20)

ax[0].hist(purchase_amount,  color = 'LawnGreen')
ax[1].hist(average_price, color = 'MediumSlateBlue')

ax[0].set_xlabel('\nСумма покупок', fontsize = 20)
ax[0].set_ylabel('Количество заказов\n', fontsize = 20)
ax[1].set_xlabel('\nСредняя цена', fontsize = 20)
ax[1].set_ylabel('Количество товаров\n', fontsize = 20)

ax[0].grid(color = 'gainsboro')
ax[1].grid(color = 'gainsboro')
ax[0].spines['right'].set_color(None)
ax[0].spines['top'].set_color(None)
ax[0].spines['left'].set_color(None)
ax[0].spines['bottom'].set_color('gainsboro')
ax[1].spines['right'].set_color(None)
ax[1].spines['top'].set_color(None)
ax[1].spines['left'].set_color(None)
ax[1].spines['bottom'].set_color('gainsboro')

# %% [markdown]
# #### 2. [1 балл] Постройте график зависимости суммы покупок от дней.

# %%
days = df.groupby('date')

fig, ax = plt.subplots(figsize=(22, 7))
ax.set_title('\nГрафик зависимости суммы покупок от дней\n', fontsize = 30)

ax.plot(np.array(days['item_price_float'].sum()), '-', color = 'DeepPink')
ax.plot(np.array(days['item_price_float'].sum()), 'o', color = 'DeepSkyBlue')

ax.set_xlabel('\nДата', fontsize = 25)
ax.set_ylabel('Сумма покупок\n', fontsize = 25)

ax.set_xticks(np.arange(len(days)))
ax.set_xticklabels(np.array(days.size().keys()), rotation = 'vertical', fontsize = 18)

ax.grid(color = 'gainsboro')
ax.spines['right'].set_color('gainsboro')
ax.spines['top'].set_color('gainsboro')
ax.spines['left'].set_color('gainsboro')
ax.spines['bottom'].set_color('gainsboro')

# %% [markdown]
# #### 3. [1 балл] Постройте средних сумм покупок по дням недели (bar plot).

# %%
df['date'] = pd.to_datetime(df['date'], format = '%Y/%m/%d')
df['Day_of_Week'] = df['date'].dt.day_name()
days_of_week = df.groupby('Day_of_Week').size().keys()
days_of_week
# Out:
# Index(['Friday', 'Monday', 'Saturday', 'Sunday', 'Thursday', 'Tuesday',
#        'Wednesday'],
#       dtype='object', name='Day_of_Week')

# %%
purchase_amount = df.groupby(['Day_of_Week', 'order_id'])['item_price_float'].sum()
purchase_amount
# Out:
# Day_of_Week  order_id
# Friday       18          24.90
#              27          13.90
#              54          15.70
#              68          21.95
#              76          10.67
#                          ...
# Wednesday    1811        29.25
#              1818        18.14
#              1827        32.95
#              1828        14.45
#              1832        13.20
# Name: item_price_float, Length: 1834, dtype: float64

# %%
average_purchase_amount = purchase_amount.groupby('Day_of_Week').mean()
average_purchase_amount
# Out:
# Day_of_Week
# Friday       18.404822
# Monday       19.722393
# Saturday     18.690934
# Sunday       18.735868
# Thursday     18.834612
# Tuesday      18.148056
# Wednesday    18.984407
# Name: item_price_float, dtype: float64

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(22, 10))
ax.set_title('\nСтолбчатый график средних сумм покупок по дням недели\n', fontsize = 30)

ax = sns.barplot(y=average_purchase_amount, x=days_of_week, palette='cool')

ax.set_xlabel('\nДень недели', fontsize = 25)
ax.set_ylabel('Средняя сумма покупок\n', fontsize = 25)
ax.set_xticks(list(range(7)))
ax.set_xticklabels(['Friday', 'Monday', 'Saturday', 'Sunday', 'Thursday', 'Tuesday', 'Wednesday'], fontsize = 18)

ax.spines['right'].set_color(None)
ax.spines['top'].set_color(None)
ax.spines['left'].set_color(None)
ax.spines['bottom'].set_color('gainsboro')

# %% [markdown]
# #### 4. [1 балл] Постройте график зависимости денег за товар от купленного количества (scatter plot).

# %%
Quantity = df['quantity']
Price = df['price_of_one_item']
Name = df['item_name']

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.set_title('\nГрафик зависимости денег за товар\n от купленного количества\n', fontsize = 22)

ax = sns.scatterplot(x = Quantity, y = Price, hue = Name)
ax.legend(loc='center left', bbox_to_anchor=(1.25, 0.5), ncol=2)

ax.set_xlabel('\nКоличество купленного товара', fontsize = 20)
ax.set_ylabel('Количетво денег за товар\n', fontsize = 20)

ax.grid(color = 'gainsboro')
ax.spines['right'].set_color('gainsboro')
ax.spines['top'].set_color('gainsboro')
ax.spines['left'].set_color('gainsboro')
ax.spines['bottom'].set_color('gainsboro')

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %%
fig.savefig("scatter.pdf", bbox_inches='tight', dpi=200)

# %% [markdown]
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.

# %% [markdown]
# ## Вывод:

# %% [markdown]
# <img src = "https://funart.pro/uploads/posts/2021-07/1626235754_23-funart-pro-p-ustavshaya-panda-zhivotnie-krasivo-foto-26.jpg">

# %% [markdown]
# Улучшила свои навыки в работе с библиотекой Pandas.
