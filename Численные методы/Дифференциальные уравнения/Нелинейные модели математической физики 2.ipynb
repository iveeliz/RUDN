# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## $- u''+ 4u-e^x\sin(2u)= -2$

# %% [markdown]
# ## $u(0) = u(1) = 0$

# %%
def Phi_function(c, N, h):
    
    sum_1 = c[1:-1] ** 2 - c[1:-1] * (c[:-2] + c[2:])
    sum_2 = 1/3 * c[1:-1] ** 2 + 1/6 * c[1:-1] * (c[:-2] + c[2:])
    sum_3 = 1/2 * np.exp(np.arange(1, N + 1)) * (np.cos(2 * c[1:-1]) - 1)
    sum_4 = c[1:-1]
                                                    
    return 1/h * np.sum(sum_1) + 4 * h * np.sum(sum_2) + h * np.sum(sum_3) + 2 * h * np.sum(sum_4)

# %%
def grad_Phi(ck, N, h):
    
    grad = np.array(0)
    j = np.arange(1, N + 1)
    
    grad = np.append(grad, 2 * ck[j] - ck[j - 1] - ck[j + 1] + 4 * h**2 * (2/3 * ck[j] + 1/6 * ck[j - 1] + 1/6 * ck[j + 1]) - h**2 * np.exp(j * h) + 2 * h**2)
    grad = np.append(grad, 0)
    
    return grad

# %%
def c_0(N, h):
    
    c_0 = np.array(0)
    j = np.arange(1, N + 1)
    c_0 = np.append(c_0, 1/2 - (np.exp(2 * j * h) + np.exp(2 - 2 * j * h)) / (2 * (1 + np.exp(2))))
    c_0 = np.append(c_0, 0)
    
    return c_0

# %%
def gradient_descent(N, h, epsilon):
    
    w = 1
    ck = c_0(N, h)
    ck1 = ck - w * grad_Phi(ck, N, h)
    
    while Phi_function(ck1, N, h) >= Phi_function(ck, N, h) and abs(abs(Phi_function(ck, N, h)) - abs(Phi_function(ck1, N, h))) >= epsilon:
        
        w = w / 2
        ck1 = ck - w * grad_Phi(ck, N, h)
        
    while abs(abs(Phi_function(ck, N, h)) - abs(Phi_function(ck1, N, h))) >= epsilon:
        
        w = 1
        ck = ck1
        ck1 = ck - w * grad_Phi(ck, N, h)
        
        while Phi_function(ck1, N, h) >= Phi_function(ck, N, h) and abs(abs(Phi_function(ck, N, h)) - abs(Phi_function(ck1, N, h))) >= epsilon:
            
            w = w / 2
            ck1 = ck - w * grad_Phi(ck, N, h)
            
    print(f'Пусть N = {N}:')
    print(f'Epsilon = {epsilon}')
    print('Коэффциент релаксации к моменту решения задачи минимизации =', w)
    
    return ck1

# %%
N = 9
x = np.linspace(0, 1, N + 2) 
h = 1 / (N + 1)
epsilon = 1e-11
u = gradient_descent(N, h, epsilon)

plt.plot(x, u, marker='.')
plt.xlabel('x')
plt.ylabel('u (x)')
plt.title(f'Приближенное решение для N = {N}')
plt.show()
# Out:
# Пусть N = 9:
# Epsilon = 1e-11
# Коэффциент релаксации к моменту решения задачи минимизации = 1.8189894035458565e-12

# %%
N = 99
x = np.linspace(0, 1, N + 2)  # N + 1 частей отрезка -> N + 2 точек разбиения
h = 1 / (N + 1)
u = gradient_descent(N, h, epsilon)

plt.plot(x, u, marker='.')
plt.xlabel('x')
plt.ylabel('u (x)')
plt.title(f'Приближенное решение для N = {N}')
plt.show()
# Out:
# Пусть N = 99:
# Epsilon = 1e-11
# Коэффциент релаксации к моменту решения задачи минимизации = 1.1368683772161603e-13
